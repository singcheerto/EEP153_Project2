# %%
# !pip install -r requirements.txt
import numpy as np
import pandas as pd

# %%
user = "justus-von-liebig"

# API key for Gov
apikey = "V0mOAdVrSineT4d2VTMTJUNPAsBTnjzUAU6e6H6V" # inIyO1begWSRqsYtxS7m6p09PSyq7Qiw7fxzV2qN"

# File with private keys for relevant service account to authenticate
# and access google spreadsheets
# !gpg -d justus_von_liebig-069d38b622a8.json.gpg > justus_von_liebig-069d38b622a8.json

serviceacct = {user:'justus_von_liebig-069d38b622a8.json'}
sheet_url = "https://docs.google.com/spreadsheets/d/1xnjnl42g_jYKdkOfW2OF7tBdGmuCAeJluT2O7fx1OQE/edit#gid=0"
# Out:
# gpg: AES encrypted data
# gpg: encrypted with 1 passphrase

# %%
import pandas as pd
from eep153_tools import read_sheets

df = pd.read_csv('groceries.csv')
df
# Out:
#     Person                      Food  Quantity   Units  Price       Date  \
# 0     Sing       Organic Silken Tofu     31.00      oz   4.98  2/28/2021
# 1     Sing              Oyster Sauce     18.00      oz   5.99  2/28/2021
# 2     Sing    Ottogi Gold Mayonnaise    500.00       g   5.99  2/28/2021
# 3     Sing           Sajo Light Tuna       NaN     NaN    NaN  2/28/2021
# 4     Sing               Sanuki Udon      2.45      lb   3.99  2/28/2021
# ..     ...                       ...       ...     ...    ...        ...
# 71  Steven           chicken breast       2.50  pounds   6.59   12/28/20
# 72  Steven         Fish Filet frozen      1.50  pounds   6.99   12/28/20
# 73  Steven  California sweet Oranges      3.00  pounds   3.19   12/28/20
# 74  Steven          Fish cake Frozen      1.00  pounds   4.99   12/28/20
# 75  Steven                 Asparagus      2.00  pounds   3.98   12/28/20
#
#            Location      FDC
# 0   KP Asian Market  1373713
# 1   KP Asian Market  1100181
# ...

# %%
import fooddatacentral as fdc

D = {}
count = 0
for food in  df.Food.tolist():
    try:
        FDC = df.loc[df.Food==food,:].FDC[count]
        count+=1
        D[food] = fdc.nutrients(apikey,FDC).Quantity
    except AttributeError: 
        warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))        

FoodNutrients = pd.DataFrame(D,dtype=float)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-4-c680915cb69f> in <module>
#       7         FDC = df.loc[df.Food==food,:].FDC[count]
#       8         count+=1
# ----> 9         D[food] = fdc.nutrients(apikey,FDC).Quantity
#      10     except AttributeError:
#      11         warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
#
# ~/EEP153_Project2/fooddatacentral.py in nutrients(apikey, fdc_id, url)
#      37         r = requests.get(url+"%s" % fdc_id, params = params)
#      38
# ---> 39         L = r.json()['foodNutrients']
#      40     except KeyError:
#      41         warnings.warn("Couldn't find fdc_id=%s." % fdc_id)
#
# /opt/conda/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# ...
